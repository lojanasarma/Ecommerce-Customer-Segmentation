# %%
import pandas as pd
import os

# -----------------------------
# 1. Load Excel file
# -----------------------------

file_path = r"C:\Users\Lojan\Desktop\Semester 3\AIML\Part_Anjali\data\online_retail_II.xlsx"

df = pd.read_excel(file_path)

print("Dataset loaded successfully!")
print("Number of rows:", len(df))
print("Number of columns:", len(df))

print("\nFirst 5 rows:")
print(df.head())

print("\nColumns:")
print(df.columns)


# -----------------------------
# 2. Remove missing Customer IDs
# -----------------------------

df = df.dropna(subset=["Customer ID"])

print("\nRows after removing missing Customer IDs:", len(df))


# -----------------------------
# 3. Remove cancelled orders
# -----------------------------

df = df[~df["Invoice"].astype(str).str.startswith("C")]

print("Rows after removing cancelled orders:", len(df))


# -----------------------------
# 4. Remove negative quantities
# -----------------------------

df = df[df["Quantity"] > 0]

print("Rows after removing negative quantities:", len(df))


# -----------------------------
# 5. Remove extreme price outliers
# -----------------------------

Q1 = df["Price"].quantile(0.25)
Q3 = df["Price"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[
    (df["Price"] >= lower_bound) &
    (df["Price"] <= upper_bound)
]

print("Rows after handling price outliers:", len(df))


# -----------------------------
# 6. Calculate Total Cost
# -----------------------------

df["TotalCost"] = df["Quantity"] * df["Price"]

print("\nTotal Cost:")
print(df[["Quantity", "Price", "TotalCost"]].head())


# -----------------------------
# 7. Dataset information
# -----------------------------

print("\nDataset information:")
df.info()


# -----------------------------
# 8. Missing values check
# -----------------------------

print("\nMissing values:")
print(df.isnull().sum())


# -----------------------------
# 9. Check negative quantities
# -----------------------------

print("\nNegative quantities:", (df["Quantity"] < 0).sum())


# -----------------------------
# 10. Check cancelled invoices
# -----------------------------

print(
    "Cancelled invoices:",
    df["Invoice"].astype(str).str.startswith("C").sum()
)


# -----------------------------
# 11. Price check
# -----------------------------

print("Minimum price:", df["Price"].min())
print("Maximum price:", df["Price"].max())


# -----------------------------
# 12. Save cleaned dataset
# -----------------------------

output_folder = r"C:\Users\Lojan\Desktop\Semester 3\AIML\Part_Anjali\outputs"

os.makedirs(output_folder, exist_ok=True)

output_path = os.path.join(
    output_folder,
    "1_cleaned_data_nayanajith.csv"
)

df.to_csv(output_path, index=False)

print("\nCleaned file saved successfully!")
print(output_path)
# Out:
# Dataset loaded successfully!
# Number of rows: 525461
# Number of columns: 525461
#
# First 5 rows:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom
#
# Columns:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='str')
#
# Rows after removing missing Customer IDs: 417534
# Rows after removing cancelled orders: 407695
# Rows after removing negative quantities: 407695
# Rows after handling price outliers: 374706
#
# Total Cost:
#    Quantity  Price  TotalCost
# 0        12   6.95       83.4
# 1        12   6.75       81.0
# 2        12   6.75       81.0
# 3        48   2.10      100.8
# 4        24   1.25       30.0
#
# Dataset information:
# <class 'pandas.DataFrame'>
# Index: 374706 entries, 0 to 525460
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      374706 non-null  object
#  1   StockCode    374706 non-null  object
#  2   Description  374706 non-null  object
#  3   Quantity     374706 non-null  int64
#  4   InvoiceDate  374706 non-null  datetime64[us]
#  5   Price        374706 non-null  float64
#  6   Customer ID  374706 non-null  float64
#  7   Country      374706 non-null  str
#  8   TotalCost    374706 non-null  float64
# dtypes: datetime64[us](1), float64(3), int64(1), object(3), str(1)
# memory usage: 28.6+ MB
#
# Missing values:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# TotalCost      0
# dtype: int64
#
# Negative quantities: 0
# Cancelled invoices: 0
# Minimum price: 0.0
# Maximum price: 7.5
#
# Cleaned file saved successfully!
# C:\Users\Lojan\Desktop\Semester 3\AIML\Part_Anjali\outputs\1_cleaned_data_nayanajith.csv

# %%
# %pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in c:\users\lojan\appdata\roaming\python\python314\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\lojan\appdata\roaming\python\python314\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
